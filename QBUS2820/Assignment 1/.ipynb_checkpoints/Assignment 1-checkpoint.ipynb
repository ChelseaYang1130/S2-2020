# %% [markdown]
# # Task 1

# %% [markdown]
# **Problem:** select 3 models to predict NBA player salary
# 1. linear regression model
# 2. KNN regression model
# 3. Random forest / Support vector machine
#
# **Data:** NBA_Train.csv, NBA_Test.csv
#
# **Metadata:** https://stats.nba.com/help/glossary/
#
# **Resonse variable:** Salary
#
# **Performance metric:** Root mean squared error (RMSE) < 4.1 ($Millions) --  at least 2/3 models have to achieve this goal

# %% [markdown]
# # Data processing and EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context('notebook')
# %matplotlib inline
sns.set_style("darkgrid")

# %%
NBA_train = pd.read_csv('NBA_Train.csv')
NBA_test = pd.read_csv('NBA_Test.csv')

# %%
# NBA_train.info()
NBA_train.describe().round(4)
# Out:
#        Train_ID    SALARY       Age     Games    Minutes       PER        TS  \
# count  126.0000  126.0000  126.0000  126.0000   126.0000  126.0000  126.0000
# mean    63.5000    6.7842   26.6825   69.4603  1809.0159   14.9643    0.5425
# std     36.5171    5.6479    4.0805   11.4330   703.5615    4.3063    0.0457
# min      1.0000    0.1114   19.0000   40.0000   393.0000    6.3000    0.4460
# 25%     32.2500    2.3852   23.0000   62.0000  1290.2500   12.4250    0.5100
# 50%     63.5000    4.5000   26.0000   72.5000  1859.0000   14.0000    0.5400
# 75%     94.7500    9.5914   29.0000   79.0000  2405.0000   16.7500    0.5678
# max    126.0000   22.9705   37.0000   82.0000  3122.0000   29.8000    0.7300
#
#             ORB       DRB       TRB       AST       STL       BLK       TOV  \
# count  126.0000  126.0000  126.0000  126.0000  126.0000  126.0000  126.0000
# mean     5.1548   15.1167   10.1365   14.4571    1.5873    1.5222   13.4865
# std      3.8254    6.0185    4.6266    9.8211    0.6176    1.3595    4.1566
# min      1.0000    6.2000    4.1000    2.1000    0.2000    0.0000    7.2000
# 25%      2.1250   10.1250    6.0250    7.0250    1.1250    0.6000   10.4000
# 50%      3.7000   13.8000    9.2000   11.2500    1.5000    1.1000   12.5000
# 75%      7.3000   19.2000   13.9000   19.9750    2.0000    1.8750   15.5000
# max     17.5000   32.1000   22.3000   44.3000    3.8000    7.4000   28.8000
#
#             USG      ORtg      DRtg       OWS       DWS        WS
# count  126.0000  126.0000  126.0000  126.0000  126.0000  126.0000
# mean    19.9897  107.1825  106.8651    2.3373    1.8397    4.1825
# std      4.9621    7.5899    3.6799    2.6395    1.1787    3.4027
# min      9.3000   88.0000   97.0000   -0.9000    0.0000   -0.1000
# 25%     16.4250  102.0000  104.0000    0.6000    0.9000    1.7250
# 50%     19.1000  107.0000  107.0000    1.6500    1.6000    3.1500
# 75%     23.2750  112.0000  110.0000    3.3000    2.4750    5.5750
# max     33.0000  130.0000  115.0000   14.8000    6.4000   19.2000

# %%
NBA_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126 entries, 0 to 125
# Data columns (total 22 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Train_ID  126 non-null    int64
#  1   SALARY    126 non-null    float64
#  2   POSITION  126 non-null    object
#  3   TEAM      126 non-null    object
#  4   Age       126 non-null    int64
#  5   Games     126 non-null    int64
#  6   Minutes   126 non-null    int64
#  7   PER       126 non-null    float64
#  8   TS        126 non-null    float64
#  9   ORB       126 non-null    float64
#  10  DRB       126 non-null    float64
#  11  TRB       126 non-null    float64
#  12  AST       126 non-null    float64
#  13  STL       126 non-null    float64
#  14  BLK       126 non-null    float64
#  15  TOV       126 non-null    float64
#  16  USG       126 non-null    float64
#  17  ORtg      126 non-null    int64
#  18  DRtg      126 non-null    int64
#  19  OWS       126 non-null    float64
#  20  DWS       126 non-null    float64
#  21  WS        126 non-null    float64
# dtypes: float64(14), int64(6), object(2)
# memory usage: 21.8+ KB

# %%
# checking missing values
NBA_train.isnull().sum()
# Out:
# Train_ID    0
# SALARY      0
# POSITION    0
# TEAM        0
# Age         0
# Games       0
# Minutes     0
# PER         0
# TS          0
# ORB         0
# DRB         0
# TRB         0
# AST         0
# STL         0
# BLK         0
# TOV         0
# USG         0
# ORtg        0
# DRtg        0
# OWS         0
# DWS         0
# WS          0
# dtype: int64

# %%
NBA_train.corr().round(3).sort_values('SALARY')
# Out:
#           Train_ID  SALARY    Age  Games  Minutes    PER     TS    ORB    DRB  \
# DRtg        -0.096  -0.266 -0.117 -0.109   -0.022 -0.301 -0.099 -0.482 -0.572
# TOV         -0.062  -0.126  0.069 -0.171   -0.220 -0.200 -0.034  0.118 -0.034
# Train_ID     1.000  -0.077  0.035  0.103    0.029  0.010  0.084  0.014  0.034
# ORB          0.014  -0.045 -0.079 -0.038   -0.283  0.120  0.046  1.000  0.752
# BLK          0.091  -0.040 -0.035 -0.097   -0.235  0.098  0.138  0.638  0.601
# Age          0.035   0.054  1.000 -0.131   -0.011  0.103  0.230 -0.079  0.052
# TRB          0.023   0.097  0.005 -0.061   -0.204  0.270  0.026  0.902  0.962
# STL          0.121   0.172 -0.007 -0.011    0.195  0.148  0.038 -0.346 -0.328
# DRB          0.034   0.173  0.052 -0.069   -0.132  0.334  0.002  0.752  1.000
# Games        0.103   0.205 -0.131  1.000    0.699  0.219  0.222 -0.038 -0.069
# TS           0.084   0.210  0.230  0.222    0.237  0.496  1.000  0.046  0.002
# ORtg         0.095   0.252  0.168  0.283    0.345  0.592  0.859  0.088 -0.005
# AST         -0.078   0.310  0.085  0.054    0.401  0.372 -0.024 -0.500 -0.384
# OWS         -0.038   0.598  0.045  0.388    0.661  0.827  0.608 -0.086  0.056
# USG         -0.067   0.620  0.032  0.138    0.495  0.746  0.032 -0.171  0.113
# Minutes      0.029   0.621 -0.011  0.699    1.000  0.543  0.237 -0.283 -0.132
# DWS          0.051   0.626  0.077  0.489    0.668  0.591  0.216  0.115  0.298
# PER          0.010   0.670  0.103  0.219    0.543  1.000  0.496  0.120  0.334
# WS          -0.009   0.678  0.061  0.470    0.743  0.844  0.545 -0.028  0.144
# SALARY      -0.077   1.000  0.054  0.205    0.621  0.670  0.210 -0.045  0.173
#
#             TRB    AST    STL    BLK    TOV    USG   ORtg   DRtg    OWS  \
# DRtg     -0.583  0.144 -0.077 -0.491 -0.115 -0.069 -0.058  1.000 -0.101
# TOV       0.029  0.350  0.249  0.117  1.000 -0.318 -0.222 -0.115 -0.212
# Train_ID  0.023 -0.078  0.121  0.091 -0.062 -0.067  0.095 -0.096 -0.038
# ORB       0.902 -0.500 -0.346  0.638  0.118 -0.171  0.088 -0.482 -0.086
# BLK       0.655 -0.447 -0.297  1.000  0.117 -0.187  0.031 -0.491 -0.118
# Age       0.005  0.085 -0.007 -0.035  0.069  0.032  0.168 -0.117  0.045
# TRB       1.000 -0.456 -0.359  0.655  0.029  0.007  0.036 -0.583  0.006
# STL      -0.359  0.452  1.000 -0.297  0.249  0.037  0.062 -0.077  0.121
# DRB       0.962 -0.384 -0.328  0.601 -0.034  0.113 -0.005 -0.572  0.056
# Games    -0.061  0.054 -0.011 -0.097 -0.171  0.138  0.283 -0.109  0.388
# TS        0.026 -0.024  0.038  0.138 -0.034  0.032  0.859 -0.099  0.608
# ORtg      0.036  0.097  0.062  0.031 -0.222  0.078  1.000 -0.058  0.726
# AST      -0.456  1.000  0.452 -0.447  0.350  0.417  0.097  0.144  0.358
# OWS       0.006  0.358  0.121 -0.118 -0.212  0.528  0.726 -0.101  1.000
# USG       0.007  0.417  0.037 -0.187 -0.318  1.000  0.078 -0.069  0.528
# Minutes  -0.204  0.401  0.195 -0.235 -0.220  0.495  0.345 -0.022  0.661
# DWS       0.249  0.210  0.211  0.146 -0.065  0.405  0.269 -0.717  0.524
# PER       0.270  0.372  0.148  0.098 -0.200  0.746  0.592 -0.301  0.827
# WS        0.088  0.350  0.168 -0.043 -0.188  0.549  0.654 -0.326  0.956
# SALARY    0.097  0.310  0.172 -0.040 -0.126  0.620  0.252 -0.266  0.598
#
#             DWS     WS
# DRtg     -0.717 -0.326
# TOV      -0.065 -0.188
# Train_ID  0.051 -0.009
# ORB       0.115 -0.028
# BLK       0.146 -0.043
# Age       0.077  0.061
# TRB       0.249  0.088
# STL       0.211  0.168
# DRB       0.298  0.144
# Games     0.489  0.470
# TS        0.216  0.545
# ORtg      0.269  0.654
# AST       0.210  0.350
# OWS       0.524  0.956
# USG       0.405  0.549
# Minutes   0.668  0.743
# DWS       1.000  0.751
# PER       0.591  0.844
# WS        0.751  1.000
# SALARY    0.626  0.678

# %%
fig, ax = plt.subplots()

cmap = sns.diverging_palette(220, 10, as_cmap= True)
sns.heatmap(NBA_train.corr(), vmax=1, vmin=-1, center=0, square=True, ax=ax, cmap=cmap)
ax.set_title('Correlation matrix', fontweight='bold', fontsize=20)
plt.tight_layout()
fig.set_size_inches(15,15)
# plt.xticks(np.arange(0.5,len(space),1),space,fontsize=20)
# plt.yticks(np.arange(0.5,len(space),1),space,fontsize=20)

# %%
with sns.axes_style('white'):
    g=sns.pairplot(NBA_train[['SALARY','WS','DWS','OWS','USG','PER','Minutes']], kind='reg',
    plot_kws={'scatter_kws' :{'color': sns.color_palette('Blues')[-1], 'alpha':
    0.4}})
plt.tight_layout()

# %%
sns.boxplot(x=NBA_train['TEAM'], y=NBA_train['SALARY'], palette='Blues')
ax.set_xlabel('Team')
ax.set_ylabel('Salary')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-5f1dca577221> in <module>
#       1 sns.boxplot(x=NBA_train['TEAM'], y=NBA_train['SALARY'], palette='Blues')
# ----> 2 ax.set_xlabel('Team')
#       3 ax.set_ylabel('Salary')
#       4 plt.show()
#
# NameError: name 'ax' is not defined

# %%
sns.boxplot(x=NBA_train['POSITION'], y=NBA_train['SALARY'], palette='Blues')
ax.set_xlabel('Position')
ax.set_ylabel('Salary')
plt.show()

# %% [markdown]
# # KNN

# %% [markdown]
# **Partial model**

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

NBA_train=NBA_train.drop(['TEAM','POSITION','Train_ID'],1)
NBA_test=NBA_test.drop(['TEAM','POSITION','Test_ID'],1)

# %%
Y_full = NBA_train['SALARY']
X_full = NBA_train.drop('SALARY',1)
X_trainF, X_valF, Y_trainF, Y_valF = train_test_split(X_full, Y_full, test_size=0.2, random_state=1)
Y_testF = NBA_test['SALARY']
X_testF = NBA_test.drop('SALARY',1)

# %%
values = np.arange(1, 101)
knnF_valerrors = []
for k in values:

    knn = KNeighborsRegressor(n_neighbors= k) 
    knn.fit(X_trainF, Y_trainF)

    knnF_pred = knn.predict(X_valF)

    val_error = np.sqrt(mean_squared_error(Y_valF, knnF_pred))

    knnF_valerrors.append(val_error)
    
fig, ax= plt.subplots()
ax.plot(values, knnF_valerrors)
ax.set_xlabel('Number of neighbours')
ax.set_ylabel('Test error')
plt.show()

# %%
# 𝑘  with lowest validation error
k = 1 + np.argmin(knnF_valerrors)
knn9F = KNeighborsRegressor(n_neighbors= k) 
knn9F.fit(X_trainF, Y_trainF)
pred_knn9F = knn9F.predict(X_testF)
test_errorF = np.sqrt(mean_squared_error(Y_testF, pred_knn9F))
test_errorF
# Out:
# 4.604189647435712

# %% [markdown]
# **WS vs SALARY**

# %%
def knn_Val(var):
    Y1 = NBA_train['SALARY']
    X1 = NBA_train.drop('SALARY',1)[var]
    X_train1, X_val1, Y_train1, Y_val1 = train_test_split(X1, Y1, test_size=0.2, random_state=1)
    Y_test1 = NBA_test['SALARY']
    X_test1 = NBA_test.drop('SALARY',1)[var]
    knn1_valerrors = []
    best_model = {}
    for k in values:

        knn = KNeighborsRegressor(n_neighbors= k) 
        knn.fit(X_train1, Y_train1)

        knn1_pred = knn.predict(X_val1)

        val_error = np.sqrt(mean_squared_error(Y_val1, knn1_pred))

        knn1_valerrors.append(val_error)

    k1 = 1 + np.argmin(knn1_valerrors)
    
    knn = KNeighborsRegressor(n_neighbors= k1) 
    knn.fit(X_train1, Y_train1)

    knn1_pred = knn.predict(X_test1)

    test_error = np.sqrt(mean_squared_error(Y_test1, knn1_pred))
    return([var,k1,min(knn1_valerrors).round(4),test_error.round(4)])

# %%
best_models = []
test_errors = {}
for i in NBA_train.drop('SALARY',1):
    var,k,val_rmse,test_error = knn_Val([i])
    best_models.append([i,k,val_rmse])
    test_errors[i]= test_error

# %%
pd.DataFrame(best_models,columns=['Variable','Number of neignbours','Validation error']).sort_values(by=['Validation error'])
# Out:
#    Variable  Number of neignbours  Validation error
# 16      DWS                    20            4.1311
# 17       WS                     8            4.1856
# 2   Minutes                     9            4.2967
# 15      OWS                    27            4.5046
# 3       PER                    18            4.7217
# 7       TRB                     5            4.7670
# 11      TOV                     8            4.8393
# 12      USG                     2            4.9401
# 6       DRB                    12            4.9470
# 13     ORtg                    12            4.9931
# 1     Games                    38            5.0979
# 14     DRtg                    17            5.1165
# 8       AST                    26            5.1572
# 10      BLK                    63            5.2531
# 9       STL                    79            5.2645
# 4        TS                    25            5.2825
# 0       Age                    89            5.3056
# 5       ORB                    93            5.3121

# %%
test_errors['WS']
# Out:
# 4.365

# %% [markdown]
# # Linear regression

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# %%
def linearVal(var):
    Y = NBA_train['SALARY']
    X = NBA_train.drop('SALARY',1)[var]
    X_train, X_val, Y_train, Y_val = train_test_split(X, Y, test_size=0.2, random_state=1)
    Y_test = NBA_test['SALARY']
    X_test = NBA_test.drop('SALARY',1)[var]

    max_deg = 10

    validation_error = {}

    for i in range(1, max_deg):
        
        poly_transformer = PolynomialFeatures(i) 
        poly_x = poly_transformer.fit_transform(X_train)

       
        lin_reg = LinearRegression()

        # Estimate coefficients
        lin_reg.fit(poly_x, Y_train)
        
        Y_predTrain = lin_reg.predict(poly_x)
        poly_xVal = poly_transformer.fit_transform(X_val)
        # Calculate predictions
        Y_predVal = lin_reg.predict(poly_xVal)

        mse_valid = np.sqrt(mean_squared_error(Y_val, Y_predVal))
        validation_error[i]=mse_valid

    min_error = np.inf

    for i in validation_error:
        if validation_error[i]<min_error:
            min_error = validation_error[i]
            degree = i
    
    poly_transformer = PolynomialFeatures(degree) 
    poly_x = poly_transformer.fit_transform(X_train)

    lin_reg = LinearRegression()

    lin_reg.fit(poly_x, Y_train)        
    poly_xTest = poly_transformer.fit_transform(X_test)
        
    Y_predTest = lin_reg.predict(poly_xTest)

    mse_test = np.sqrt(mean_squared_error(Y_test, Y_predTest))
    
    return degree,min_error,mse_test

# %%
full_model = list(NBA_train.drop('SALARY',1).columns)

# %%
print(linearVal(full_model))

# %%
lin_error = []
# pd.DataFrame(columns=['Variable','Validation error','Polynomial degree'])
for i in full_model:
    degree,val_error,test_error = linearVal([i])
    lin_error.append([i,degree,val_error,test_error])

pd.DataFrame(lin_error,columns=['Variable','Polynomial degree','Validation error','Test error']).sort_values(by=['Validation error'])
# Out:
#    Variable  Polynomial degree  Validation error  Test error
# 16      DWS                  3          3.934346    4.739813
# 2   Minutes                  4          4.167400    4.460477
# 15      OWS                  5          4.286453    4.338591
# 17       WS                  2          4.340583    4.096469
# 3       PER                  1          4.519173    4.579034
# 11      TOV                  7          5.044902   36.783109
# 12      USG                  1          5.065652    5.283241
# 7       TRB                  9          5.074950    5.541751
# 4        TS                  6          5.112224    5.942096
# 1     Games                  1          5.121587    5.296577
# 8       AST                  3          5.163710    5.466374
# 13     ORtg                  1          5.180198    5.181426
# 6       DRB                  1          5.208870    5.388165
# 14     DRtg                  9          5.266459    5.804829
# 10      BLK                  3          5.273600    5.460934
# 9       STL                  1          5.335643    5.372181
# 5       ORB                  1          5.336013    5.475338
# 0       Age                  1          5.488715    5.433702

# %%
linearVal(['DWS','Minutes'])
# Out:
# (9, 3.7211489592169307, 5.14925184478298)

# %% [markdown]
# # MLR

# %%
full_model.
# Out:
# ['Age',
#  'Games',
#  'Minutes',
#  'PER',
#  'TS',
#  'ORB',
#  'DRB',
#  'TRB',
#  'AST',
#  'STL',
#  'BLK',
#  'TOV',
#  'USG',
#  'ORtg',
#  'DRtg',
#  'OWS',
#  'WS']

# %%
from sklearn.feature_selection import RFE
from sklearn.svm import SVR
Y = NBA_train['SALARY']
X = NBA_train.drop(['SALARY','DWS'],1)
X_train, X_val, Y_train, Y_val = train_test_split(X, Y, test_size=0.2, random_state=1)
Y_test = NBA_test['SALARY']
X_test = NBA_test.drop(['SALARY','DWS'],1)
models = []
min_mse = np.inf

for j in list(X_train.columns): # different variable
    for i in range(1,11): # number of degree
        poly_transformer = PolynomialFeatures(i) 
        poly_x_train = poly_transformer.fit_transform(X_train[[j]])
        lin_reg = LinearRegression()

        selector = RFE(lin_reg, n_features_to_select=i, step=1)
        selector = selector.fit(poly_x_train,Y_train)
        
        poly_x_val = poly_transformer.fit_transform(X_val[[j]])
        Y_predVal = selector.predict(poly_x_val)
        mse_val = np.sqrt(mean_squared_error(Y_val, Y_predVal))
        
        poly_x_test = poly_transformer.fit_transform(X_test[[j]])
        Y_predTest = selector.predict(poly_x_test)
        mse_test = np.sqrt(mean_squared_error(Y_test, Y_predTest))

        models.append([j,i,mse_val,mse_test])
        
#         if mse_val < min_mse:
#             min_mse = mse_val
#             degree = i
#             var = j
#             poly_x_test = poly_transformer.fit_transform(X_test[[j]])
#             Y_predTest = selector.predict(poly_x_test)
#             mse_test = np.sqrt(mean_squared_error(Y_test, Y_predTest))

# print(var,degree,min_mse,mse_test)

        if mse_test <4.1:
            print(mse_val,mse_test)
            print(selector.support_)
            print(j)

models = pd.DataFrame(models,columns=['Variable','Polynomial degree','Validation error','Test error']).sort_values('Validation error')
# test_errors
models
# Out:
# 4.361684555157517 4.098676933641305
# [False  True]
# WS
# 4.340583119754462 4.096469324248647
# [False  True  True]
# WS
# 4.3508425789709015 4.09576303126117
# [False  True  True  True]
# WS
#     Variable  Polynomial degree  Validation error  Test error
# 23   Minutes                  4          4.167404    4.460478
# 24   Minutes                  5          4.168240    4.471126
# 25   Minutes                  6          4.175951    4.481916
# 26   Minutes                  7          4.183341    4.487616
# 27   Minutes                  8          4.190273    4.492041
# ..       ...                ...               ...         ...
# 158      OWS                  9        274.048657    5.055474
# 48        TS                  9        610.004992  282.853481
# 49        TS                 10       1638.359028  157.496345
# 169       WS                 10       2402.254195    5.161624
# 159      OWS                 10       3203.098033   10.266361
#
# [170 rows x 4 columns]

# %%
# mlr with Recursive Feature Elimination

test_errors = []
for i in range(1,18):
    estimator = SVR(kernel="linear")
    selector = RFE(estimator, n_features_to_select=i, step=1)
    selector = selector.fit(X_train,Y_train)
    Y_predVal = selector.predict(X_val)
    
    Y_predTest = selector.predict(X_test)
    # selector.support_
    mse_val = np.sqrt(mean_squared_error(Y_val, Y_predVal))
    mse_test = np.sqrt(mean_squared_error(Y_test, Y_predTest))
    
    test_errors.append(mse_test)
    print(mse_val,mse_test)
    print(selector.support_)
# test_errors

# %%
test_errors = []
for i in range(1,18):
    estimator = LinearRegression()
    selector = RFE(estimator, n_features_to_select=i, step=1)
    selector = selector.fit(X_train,Y_train)
    Y_predTest = selector.predict(X_test)
    # selector.support_
    mse_test = np.sqrt(mean_squared_error(Y_test, Y_predTest))

    test_errors.append(mse_test)
test_errors

# %%
print(selector.support_)
X

# %%
import statsmodels.api as sm

def MLR(var):
    Y = NBA_train['SALARY']
    X = NBA_train.drop('SALARY',1)[var]
    X_train, X_val, Y_train, Y_val = train_test_split(X, Y, test_size=0.2, random_state=1)
    Y_test = NBA_test['SALARY']
    X_test = NBA_test.drop('SALARY',1)[var]
    mlr = sm.OLS(Y_train,X_train)
    mlr_model = mlr.fit()
    val_pred = mlr_model.predict(X_val)
    
    test_pred = mlr_model.predict(X_test)
    
    mse_val = np.sqrt(mean_squared_error(Y_val, val_pred))
    
    mse_test = np.sqrt(mean_squared_error(Y_test, test_pred))

    return mse_val, mse_test

# %%
MLR(full_model)

# %%
print(MLR(['DWS','PER']))
print(MLR(['DWS','Minutes']))

# %% [markdown]
# # Other machine learning techique

# %%
def svmVal(var):
    Y = NBA_train['SALARY']
    X = NBA_train.drop('SALARY',1)[var]
    X_train, X_val, Y_train, Y_val = train_test_split(X, Y, test_size=0.2, random_state=1)
    Y_test = NBA_test['SALARY']
    X_test = NBA_test.drop('SALARY',1)[var]
    from sklearn import svm
    svm = svm.SVC()
    svm.fit(X_train, Y_train)
    val_pred = svm.predict(X_val)

# %%
svmVal(['Games'])
